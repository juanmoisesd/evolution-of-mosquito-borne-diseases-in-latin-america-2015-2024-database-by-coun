# %% [markdown]
# # Ejemplo: Dataset on the evolution of mosquito-borne diseases in Latin America and the Car
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juanmoisesd/evolution-of-mosquito-borne-diseases-in-latin-america-2015-2024-database-by-coun/blob/main/EXAMPLE_NOTEBOOK.ipynb)
#
# **DOI:** https://juanmoisesd.github.io/evolution-of-mosquito-borne-diseases-in-latin-america-2015-2024-database-by-coun/ | **Author:** de la Serna, Juan Moisés

# %%
# !pip install pandas matplotlib seaborn numpy -q
import pandas as pd,matplotlib.pyplot as plt,seaborn as sns,numpy as np
plt.style.use("seaborn-v0_8-whitegrid")
print("Ready")

# %%
# Full data: https://juanmoisesd.github.io/evolution-of-mosquito-borne-diseases-in-latin-america-2015-2024-database-by-coun/
np.random.seed(42)
cc=["Brazil","Mexico","Argentina","Colombia","Chile","Peru"]
rows=[{"country":c,"year":y,"value":round(np.random.uniform(8,25)+i*0.3,2)} for c in cc for i,y in enumerate(range(2015,2026))]
df=pd.DataFrame(rows)
df.head()

# %%
fig,ax=plt.subplots(figsize=(10,4))
for c in cc:
    s=df[df.country==c]
    ax.plot(s.year,s.value,marker="o",ms=3,label=c)
ax.set_title("Dataset on the evolution of mosquito-borne disease",fontweight="bold")
ax.legend(fontsize=8,ncol=3)
plt.tight_layout()
plt.savefig("example_plot.png",dpi=150,bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Cite
# ```
# de la Serna, Juan Moisés (2025). Dataset on the evolution of mosquito-borne diseases in Latin America and the Car. Zenodo. https://juanmoisesd.github.io/evolution-of-mosquito-borne-diseases-in-latin-america-2015-2024-database-by-coun/
# ```
#
# [Zenodo](https://juanmoisesd.github.io/evolution-of-mosquito-borne-diseases-in-latin-america-2015-2024-database-by-coun/) | [GitHub](https://github.com/juanmoisesd/evolution-of-mosquito-borne-diseases-in-latin-america-2015-2024-database-by-coun) | [Colab](https://colab.research.google.com/github/juanmoisesd/evolution-of-mosquito-borne-diseases-in-latin-america-2015-2024-database-by-coun/blob/main/EXAMPLE_NOTEBOOK.ipynb)
